# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
from scipy import stats
import statistics

# %%
df = pd.read_csv("householdtask3.csv")

# %%
df.head(10)
# Out:
#    year  tot_hhs      own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 0  2008  1560859  1087580  574406      69.7         36.8     100.0  35.9
# 1  2008   185965    71256   39405      38.3         21.2      11.9  29.9
# 2  2008   312376   191470   48424      61.3         15.5      20.0  40.0
# 3  2008   312333   196203   84171      62.8         26.9      20.0  34.7
# 4  2008   312240   217657  141318      69.7         45.3      20.0  31.5
# 5  2008   312336   229014  147658      73.3         47.3      20.0  35.3
# 6  2008   311574   253235  152835      81.3         49.1      20.0  39.3
# 7  2008   312761   194358   49448      62.1         15.8      20.0  38.7
# 8  2008   311973   206342   86390      66.1         27.7      20.0  36.1
# 9  2008   311840   194361  108065      62.3         34.7      20.0  33.0
#
#    size  income  expenditure  eqv_income  eqv_exp
# 0   2.7   46704        42394       26869    25132
# 1   2.6   23404        25270       14258    15824
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         70 non-null     int64
#  1   tot_hhs      70 non-null     int64
#  2   own          70 non-null     int64
#  3   own_wm       70 non-null     int64
#  4   own_prop     70 non-null     float64
#  5   own_wm_prop  70 non-null     float64
#  6   prop_hhs     70 non-null     float64
#  7   age          70 non-null     float64
#  8   size         70 non-null     float64
#  9   income       70 non-null     int64
#  10  expenditure  70 non-null     int64
#  11  eqv_income   70 non-null     int64
#  12  eqv_exp      70 non-null     int64
# dtypes: float64(5), int64(8)
# memory usage: 7.2 KB

# %%
df.describe(include='all')
# Out:
#               year       tot_hhs           own         own_wm   own_prop  \
# count    70.000000  7.000000e+01  7.000000e+01      70.000000  70.000000
# mean   2014.000000  4.125193e+05  2.689711e+05  129639.457143  63.505714
# std       4.273274  3.491547e+05  2.385230e+05  128627.124758  15.145257
# min    2008.000000  1.322150e+05  3.008000e+04   14220.000000  22.800000
# 25%    2011.000000  3.123460e+05  1.838408e+05   50636.750000  55.400000
# 50%    2014.000000  3.276340e+05  2.153065e+05  107909.000000  64.200000
# 75%    2017.000000  3.468958e+05  2.604148e+05  147563.000000  73.675000
# max    2020.000000  1.756740e+06  1.125000e+06  574662.000000  88.100000
#
#        own_wm_prop    prop_hhs        age       size         income  \
# count    70.000000   70.000000  70.000000  70.000000      70.000000
# mean     30.348571   24.985714  38.284286   2.625714   56694.785714
# std      14.010004   21.102368   9.376345   0.350439   28921.315551
# ...

# %%
df.isnull().sum()
# Out:
# year           0
# tot_hhs        0
# own            0
# own_wm         0
# own_prop       0
# own_wm_prop    0
# prop_hhs       0
# age            0
# size           0
# income         0
# expenditure    0
# eqv_income     0
# eqv_exp        0
# dtype: int64

# %% [markdown]
# scatter plot with year vs own

# %%
sns.scatterplot( x= df['year'], y = df['own'] ,data = df)
# Out:
# <Axes: xlabel='year', ylabel='own'>

# %%
plt.scatter(df['year'], df['own'])
plt.title('Scatter plot')
plt.xlabel('year')
plt.ylabel('own')
plt.show()

# %% [markdown]
# Line chart / Line plot with year v/s own

# %%
plt.plot(df['year'])
plt.plot(df['own'])
plt.title('Line Chart')
plt.xlabel('year')
plt.ylabel('own')
plt.show()

# %%
plt.plot(df[['year','own']])
plt.title('Line Chart')
plt.xlabel('year')
plt.ylabel('own')
plt.show()

# %%
sns.lineplot(x=df['year'], y=df['own'], data=df)
# Out:
# d:\ANACONDA_Jupyter2024\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# d:\ANACONDA_Jupyter2024\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='year', ylabel='own'>

# %% [markdown]
# Histogram Plot with income

# %%
plt.hist(df['income'])
plt.title('Histogram')

plt.show()

# %%
plt.hist(df['income'], bins=10)
plt.title('Histogram')

plt.show()

# %%
plt.hist(df['income'], bins=20)
plt.title('Histogram')

plt.show()

# %%
plt.hist(df['income'], bins=50, color = 'red')
plt.title('Histogram')

plt.show()

# %%
sns.histplot(df['income'])
# Out:
# d:\ANACONDA_Jupyter2024\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='income', ylabel='Count'>

# %% [markdown]
# bar-plot with year and own

# %%
plt.bar(df['year'], df['own'])
plt.title('Bar chart')
plt.xlabel('year')
plt.ylabel('own')
plt.show()

# %%
sns.barplot(x= df['year'], y = df['own'], data=df)
# Out:
# <Axes: xlabel='year', ylabel='own'>

# %%
sns.barplot(x= df['year'], y = df['own'], data=df)
plt.title('Bar-Plot')
plt.show()

# %% [markdown]
# COUNTPLOT

# %%
sns.countplot(x  = df['year'], data =df)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
sns.countplot(x  = df['year'], data =df)
plt.title('Count-Plot')
plt.show()
